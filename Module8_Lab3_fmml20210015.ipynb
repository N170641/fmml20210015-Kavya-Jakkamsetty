# %% [markdown]
# <a href="https://colab.research.google.com/github/N170641/fmml20210015-Kavya-Jakkamsetty/blob/main/Module8_Lab3_fmml20210015.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-20 12:18:55--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   146MB/s    in 0.5s
#
# 2022-06-20 12:18:56 (146 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 40698  1604.00557v1  Recent years have seen an increasing interest ...    cs
# 29223  1708.07878v1  We propose Stereo Direct Sparse Odometry (Ster...    cs
# 26895  1701.02166v1  State-of-the-art techniques for 6D object pose...    cs
# 22505  1610.04811v2  Density matrices are positively semi-definite ...  stat
# 14795   1306.6130v1  My system utilizes the outcomes feature found ...    cs
# ...             ...                                                ...   ...
# 22115   1412.7260v2  High-dimensional data often lie in low-dimensi...  stat
# 10378   1304.2302v1  The Dirichlet process (DP) is a fundamental ma...  stat
# 1104   1709.09161v1  Deep neural networks continue to show improved...  stat
# 632    1703.00096v2  Most existing sequence labelling models rely o...    cs
# 34884   1209.2918v3  The distance between a pair of spike trains, q...    cs
#
#                                                    title  year  \
# 40698  SAM: Support Vector Machine Based Active Queue...  2016
# 29223  Stereo DSO: Large-Scale Direct Sparse Visual O...  2017
# 26895  A Learning-based Variable Size Part Extraction...  2017
# 22505  Estimation of low rank density matrices by Pau...  2016
# 14795  Competency Tracking for English as a Second or...  2013
# ...                                                  ...   ...
# 22115  Approximate Subspace-Sparse Recovery with Corr...  2014
# 10378  ClusterCluster: Parallel Markov Chain Monte Ca...  2013
# 1104   EDEN: Evolutionary Deep Networks for Efficient...  2017
# 632    Gram-CTC: Automatic Unit Selection and Target ...  2017
# 34884            A new class of metrics for spike trains  2012
#
#                                                 keywords
# 40698  [increasing, controllers, controllers, congest...
# 29223  [estimation, environments, optimizes, paramete...
# 26895  [techniques, occlusion, accurately, shortcomin...
# 22505  [positively, hermitian, represented, dimension...
# 14795  [management, competencies, competencies, compe...
# ...                                                  ...
# 22115  [dimensional, dimensional, subspaces, correspo...
# 10378  [dirichlet, fundamental, mathematical, nonpara...
# 1104   [performance, increasing, encouraging, explosi...
# 632    [labelling, decomposition, drawbacks, characte...
# 34884  [quantifying, differences, introduce, hausdorf...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 40698    [increasing, controllers, controllers, congest...
# 29223    [estimation, environments, optimizes, paramete...
# 26895    [techniques, occlusion, accurately, shortcomin...
# 22505    [positively, hermitian, represented, dimension...
# 14795    [management, competencies, competencies, compe...
#                                ...
# 22803    [interactions, homogeneous, processes, modelli...
# 5105     [monocular, relocalization, convolutional, add...
# 9576     [demonstrated, performing, inference, requirin...
# 23533    [collection, algorithms, similarity, transform...
# 7132     [framework, differentially, perturbation, diff...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8854 words.
# Out of those 4553 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="349bf171-bcbc-4bcd-bf7d-43af8557cac2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("349bf171-bcbc-4bcd-bf7d-43af8557cac2")) {                    Plotly.newPlot(                        "349bf171-bcbc-4bcd-bf7d-43af8557cac2",                        [{"x":["efficient","preliminary","detection","controlling","management","congestion","controller","simulation","controllers","bandwidth","conventional","proportional","comparable","performance","increasing","constraints","shortcomings","alignment","adjustment","intensity","sufficient","outperforms","keyframes","providing","optimizes","particular","estimation","parameters","uniformly","robustness","environments","evaluation","reconstruction","integrate","demonstrates","optimization","sensitivities","approaches","including","quantitative","iterative","automatic","extracted","available","represented","estimating","extraction","shortcoming","iteratively","introduced","framework","introduce","histogram","volumetric","occlusion","candidate","architecture","inference","accurately","descriptors","discriminative","cluttered","accomplished","refinement","leveraged","description","techniques","conducted","registration","experiments","information","convergence","observation","conducting","condition","conditions","measurements","dimensional","tomography","establish","contribution","simultaneously","hermitian","projection","estimators","positively","distances","objective","divergence","estimator","regression","enrollment","curriculum","accomplishments","competency","algorithm","implementation","algorithms","preserved","illustrate","experimentally","sacrificing","incremental","effective","guarantee","benchmark","computing","stochastic","randomized","guarantees","iteration","iterations","desirable","variables","regularization","coordinate","effectiveness","particularly","operations","structure","efficiency","postprocessing","demonstrate","capability","preprocessing","excellent","distribution","parallelize","reformulated","appropriate","development","computations","keypoints","descriptor","competitive","accelerate","segmentation","convolutional","different","acceptable","attribute","myocardial","unnecessary","drawbacks","analytics","literature","incorporate","classification","considers","prediction","validated","potentially","practiced","discharge","discriminate","transition","calibration","probability","predictive","healthcare","administrative","administration","discrimination","infarction","predicted","pulmonary","hospitalized","interventions","readmission","readmissions","readmitted","generalized","normality","orthogonal","parametric","estimates","primarily","asymptotic","minimization","empirical","splitting","expository","technical","alternative","consistency","investigate","historical","complexity","euclidean","validation","summarize","applications","difficult","scalability","discussed","overfitting","computation","determine","unfortunately","electrocardiograms"],"y":[391,50,356,16,29,2,21,68,11,9,106,18,97,892,108,154,12,44,13,40,85,248,4,84,12,239,206,253,15,107,91,242,99,44,48,351,2,421,254,67,64,191,118,301,81,63,143,4,37,136,565,315,17,14,24,51,253,202,57,33,95,14,7,32,10,80,344,58,21,622,681,120,60,6,45,130,61,182,22,50,76,123,1,45,12,5,34,180,32,24,128,3,5,2,2,829,151,585,15,73,52,3,26,260,24,190,143,162,20,72,45,33,36,123,81,29,208,97,67,336,138,2,621,44,28,26,235,4,8,73,133,28,9,24,119,23,224,388,742,5,38,1,9,19,8,122,62,537,29,215,31,31,2,3,11,24,24,173,60,9,0,1,17,1,59,4,1,8,1,1,1,73,3,12,36,79,15,27,75,173,14,1,43,95,62,130,23,234,34,55,17,425,161,40,60,30,162,76,33,1],"type":"bar"},{"x":["efficient","preliminary","detection","controlling","management","congestion","controller","simulation", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4553,), (4553, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8183333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Generic</span> <span style=''>Sketch</span> <span style=''>Based</span> <span style='background-color:rgba(0, 255, 0, 0.576271186440678);'>Retrieval</span> <span style=''>Learned</span> <span style=''>without</span> <span style=''>Drawing</span> <span style=''>a</span> <span style=''>Single</span> <span style=''>Sketch</span> <br/><br/><span style=''>We</span> <span style=''>cast</span> <span style=''>the</span> <span style=''>sketch</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.576271186440678);'>retrieval</span> <span style=''>as</span> <span style=''>edge</span> <span style=''>map</span> <span style=''>matching</span> <span style=''>A</span> <span style=''>shared</span> <span style='background-color:rgba(0, 255, 0, 0.6405919661733616);'>convolutional</span> <span style=''>network</span> <span style=''>is</span> <span style=''>trained</span> <span style=''>to</span> <span style=''>extract</span> <span style='background-color:rgba(0, 255, 0, 0.6097560975609756);'>descriptors</span> <span style=''>from</span> <span style=''>edge</span> <span style=''>maps</span> <span style=''>and</span> <span style=''>sketches</span> <span style=''>which</span> <span style=''>are</span> <span style=''>treated</span> <span style=''>as</span> <span style=''>a</span> <span style=''>special</span> <span style=''>case</span> <span style=''>of</span> <span style=''>edge</span> <span style=''>maps</span> <span style=''>The</span> <span style=''>network</span> <span style=''>is</span> <span style=''>fine</span> <span style=''>tuned</span> <span style=''>solely</span> <span style=''>from</span> <span style=''>edge</span> <span style=''>maps</span> <span style=''>of</span> <span style=''>landmark</span> <span style=''>images</span> <span style=''>The</span> <span style=''>training</span> <span style=''>images</span> <span style=''>are</span> <span style=''>acquired</span> <span style=''>in</span> <span style=''>a</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsupervised</span> <span style=''>manner</span> <span style=''>from</span> <span style=''>3D</span> <span style=''>landmark</span> <span style=''>models</span> <span style=''>obtained</span> <span style=''>by</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.37007874015748043);'>automated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>from</span> <span style=''>motion</span> <span style=''>pipeline</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>achieves</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>results</span> <span style=''>on</span> <span style=''>a</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>benchmark</span> <span style=''>On</span> <span style=''>two</span> <span style=''>other</span> <span style=''>fine</span> <span style=''>grained</span> <span style=''>sketch</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.576271186440678);'>retrieval</span> <span style='background-color:rgba(0, 255, 0, 0.450381679389313);'>benchmarks</span> <span style=''>it</span> <span style=''>performs</span> <span style=''>on</span> <span style=''>par</span> <span style=''>with</span> <span style=''>or</span> <span style=''>comes</span> <span style=''>just</span> <span style=''>after</span> <span style=''>the</span> <span style=''>method</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specifically</span> <span style=''>designed</span> <span style=''>for</span> <span style=''>the</span> <span style=''>dataset</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Sampling</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style=''>Models</span> <span style=''>with</span> <span style=''>Fast</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Quadrature</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>models</span> <span style=''>an</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>approach</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>converges</span> <span style=''>more</span> <span style=''>quickly</span> <span style=''>(in</span> <span style=''>wall</span> <span style=''>clock</span> <span style=''>time)</span> <span style=''>than</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>(MCMC)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmarks</span> <span style=''>The</span> <span style=''>central</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integration</span> <span style=''>to</span> <span style=''>average</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ensembles</span> <span style=''>of</span> <span style=''>models</span> <span style=''>or</span> <span style=''>unknown</span> <span style=''>(hyper</span> <span style=''>)parameters</span> <span style=''>(for</span> <span style=''>example</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>the</span> <span style=''>marginal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>or</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partition</span> <span style=''>function)</span> <span style=''>MCMC</span> <span style=''>has</span> <span style=''>provided</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integration</span> <span style=''>that</span> <span style=''>deliver</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>but</span> <span style=''>can</span> <span style=''>suffer</span> <span style=''>from</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inefficiency</span> <span style=''>and</span> <span style=''>poor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diagnostics</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quadrature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>offer</span> <span style=''>a</span> <span style=''>model</span> <span style=''>based</span> <span style=''>solution</span> <span style=''>to</span> <span style=''>such</span> <span style=''>problems</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Ranking</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3913043478260869);'>Dependence</span> <span style=''>A</span> <span style=''>Fair</span> <span style=''>Criteria</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3505154639175258);'>Estimating</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependences</span> <span style=''>between</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.40291262135922334);'>variables</span> <span style=''>and</span> <span style=''>ranking</span> <span style=''>them</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accordingly</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.39999999999999986);'>prevalent</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>Pursuing</span> <span style='background-color:rgba(255, 0, 0, 0.846153846153846);'>frequentist</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>we</span> <span style=''>first</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>p</span> <span style=''>value</span> <span style=''>and</span> <span style=''>the</span> <span style=''>mutual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>can</span> <span style=''>fail</span> <span style=''>even</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.75);'>simplistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>situations</span> <span style=''>We</span> <span style=''>then</span> <span style=''>propose</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularizing</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.701863354037267);'>estimator</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3913043478260869);'>dependence</span> <span style=''>which</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>yet</span> <span style='background-color:rgba(0, 255, 0, 0.31313131313131315);'>effective</span> <span style=''>new</span> <span style=''>measure</span> <span style=''>We</span> <span style=''>discuss</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantages</span> <span style=''>and</span> <span style=''>compare</span> <span style=''>it</span> <span style=''>to</span> <span style=''>well</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>established</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>criteria</span> <span style=''>Apart</span> <span style=''>from</span> <span style=''>that</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraint</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularizing</span> <span style='background-color:rgba(255, 0, 0, 0.3141210374639769);'>parameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimates</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>model</span> <span style=''>This</span> <span style=''>results</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Multiclass</span> <span style=''>Boosting</span> <br/><br/><span style=''>Recent</span> <span style=''>work</span> <span style=''>has</span> <span style=''>extended</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>boosting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiclass</span> <span style=''>problems</span> <span style=''>and</span> <span style=''>to</span> <span style=''>online</span> <span style=''>settings</span> <span style=''>However</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiclass</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>is</span> <span style=''>in</span> <span style=''>the</span> <span style=''>batch</span> <span style=''>setting</span> <span style=''>and</span> <span style=''>the</span> <span style=''>online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensions</span> <span style=''>only</span> <span style=''>consider</span> <span style=''>binary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>We</span> <span style=''>fill</span> <span style=''>this</span> <span style=''>gap</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>by</span> <span style=''>defining</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>justifying</span> <span style=''>a</span> <span style=''>weak</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>condition</span> <span style=''>for</span> <span style=''>online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiclass</span> <span style=''>boosting</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>condition</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>an</span> <span style=''>optimal</span> <span style=''>boosting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>requires</span> <span style=''>the</span> <span style=''>minimal</span> <span style=''>number</span> <span style=''>of</span> <span style=''>weak</span> <span style=''>learners</span> <span style=''>to</span> <span style=''>achieve</span> <span style=''>a</span> <span style=''>certain</span> <span style=''>accuracy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Additionally</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>adaptive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>is</span> <span style=''>near</span> <span style=''>optimal</span> <span style=''>and</span> <span style=''>enjoys</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>excellent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>on</span> <span style=''>real</span> <span style=''>data</span> <span style=''>due</span> <span style=''>to</span> <span style=''>its</span> <span style=''>adaptive</span> <span style=''>property</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12633451957295375)
# 	representation (0.12704626334519573)
# 	architecture (0.0900355871886121)
# 	information (0.24234875444839857)
# 	experimental (0.1398576512455516)
# 	segmentation (0.0797153024911032)
# 	detection (0.12669039145907474)
# 	recognition (0.12669039145907474)
# 	different (0.2640569395017794)
# 	convolutional (0.13807829181494663)
#
# Some Statistics words are:
# 	stochastic (0.13919597989949747)
# 	algorithm (0.3844221105527638)
# 	estimation (0.17035175879396985)
# 	theoretical (0.15527638190954773)
# 	distribution (0.18391959798994975)
# 	variables (0.14522613065326634)
# 	statistical (0.1542713567839196)
# 	dimensional (0.19396984924623115)
# 	inference (0.20351758793969849)
# 	regression (0.18643216080402011)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="defa248f-e65a-4899-8bdc-15edcafe46d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("defa248f-e65a-4899-8bdc-15edcafe46d9")) {                    Plotly.newPlot(                        "defa248f-e65a-4899-8bdc-15edcafe46d9",                        [{"x":["efficient","preliminary","detection","controlling","management","congestion","controller","simulation","controllers","bandwidth","conventional","proportional","comparable","performance","increasing","constraints","shortcomings","alignment","adjustment","intensity","sufficient","outperforms","keyframes","providing","optimizes","particular","estimation","parameters","uniformly","robustness","environments","evaluation","reconstruction","integrate","demonstrates","optimization","sensitivities","approaches","including","quantitative","iterative","automatic","extracted","available","represented","estimating","extraction","shortcoming","iteratively","introduced","framework","introduce","histogram","volumetric","occlusion","candidate","architecture","inference","accurately","descriptors","discriminative","cluttered","accomplished","refinement","leveraged","description","techniques","conducted","registration","experiments","information","convergence","observation","conducting","condition","conditions","measurements","dimensional","tomography","establish","contribution","simultaneously","hermitian","projection","estimators","positively","distances","objective","divergence","estimator","regression","enrollment","curriculum","accomplishments","competency","algorithm","implementation","algorithms","preserved","illustrate","experimentally","sacrificing","incremental","effective","guarantee","benchmark","computing","stochastic","randomized","guarantees","iteration","iterations","desirable","variables","regularization","coordinate","effectiveness","particularly","operations","structure","efficiency","postprocessing","demonstrate","capability","preprocessing","excellent","distribution","parallelize","reformulated","appropriate","development","computations","keypoints","descriptor","competitive","accelerate","segmentation","convolutional","different","acceptable","attribute","myocardial","unnecessary","drawbacks","analytics","literature","incorporate","classification","considers","prediction","validated","potentially","practiced","discharge","discriminate","transition","calibration","probability","predictive","healthcare","administrative","administration","discrimination","infarction","predicted","pulmonary","hospitalized","interventions","readmission","readmissions","readmitted","generalized","normality","orthogonal","parametric","estimates","primarily","asymptotic","minimization","empirical","splitting","expository","technical","alternative","consistency","investigate","historical","complexity","euclidean","validation","summarize","applications","difficult","scalability","discussed","overfitting","computation","determine","unfortunately","electrocardiograms","characteristics","organizes","polynomial","monotonicity","numerical","intervals","synthetic","stability","regressor","linearity","piecewise","vocabulary","regressors","benchmarks","decomposable","combinatorial","likelihood","polytopes","relaxations","structures","graphical","undirected","searching","independently","treewidth","classical","optimality","reinforcement","hyperbolic","theoretical","assumptions","limitations","evaluated","outperform","configurations","efficiently","principle","considering","collection","parameter","structural","individual","selection","empirically","conservative","theoretic","existence","interpolants","characterizations","extensions","expressive","foundations","procedures","interpolation","forgetting","applicable","g ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	administrative
# 	hoeffdings
# 	boundedness
# 	composers
# 	equitable
# 	equitability
# 	exchangeable
# 	continuum
# 	reversing
# 	percolation
# 	continuing
# 	seriously
# 	isometrically
# 	prognostics
# 	blockmodel
# 	extrapolation
# 	uncollapsed
# 	profitable
# 	nonconvexity
# 	truncation
# Some words which never appear in Statistics papers:
# 	congestion
# 	keyframes
# 	sensitivities
# 	cluttered
# 	curriculum
# 	accomplishments
# 	competency
# 	reformulated
# 	organizes
# 	regressor
# 	treewidth
# 	identifier
# 	connective
# 	discourse
# 	registering
# 	millimeter
# 	annotating
# 	subsuming
# 	decidable
# 	generalising

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.062505742198267e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7633333333333333
